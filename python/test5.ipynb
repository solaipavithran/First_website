# %%
from classa.Atest import Car
from classa.Btest import MotorCycle
obj1 = MotorCycle()
obj2 = Car()

print(obj1.specific_usage())
print(obj2.specific_usage())
# Out:
# I am motor cycle
# i am car
# MotorCycle
# 2
# car
# 4

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None

class linkedlist:
    def __init__(self):
        self.head = None
    def insert_E(self):
        Node()

# %%
class student:
    def __init__(self):
        self.l = []
    def get_data(self,id,name,age):
        self.l.append((id,name,age))
    def display(self):
        print(self.l)
    def removel(self,r):
        for i in self.l:
            if r in i:
                self.l.remove(i)

o = student()
o.get_data(1,'pavithran',21)
o.get_data(2,'Alice',21)
o.get_data(3,'Bob',22)
o.get_data(4,'Charlie',28)
o.get_data(5,'v',23)
o.display()
# Out:
# [(1, 'pavithran', 21), (2, 'Alice', 21), (3, 'Bob', 22), (4, 'Charlie', 28), (5, 'v', 23)]

# %%
class student:
    def __init__(self):
        self.l = []
    def get_data(self,id,name,age):
        self.l.append((id,name,age))
    def display(self):
        print(self.l)
    def removel(self,r):
        for i in self.l:
            if r in i:
                self.l.remove(i)

o = student()
o.get_data(1,'pavithran',21)
o.get_data(2,'Alice',21)
o.get_data(3,'Bob',22)
o.get_data(4,'Charlie',28)
o.get_data(5,'v',23)
#o.display()

class mark(student):
    def __init__(self):
        super().__init__()
        #print(self.l)
        self.k = []

    '''def total(self,id,mark):
        self.s= 0
        self.Id = id
        for i in mark:
            self.s += i
        self.l1.append(id)
        self.l1.append(mark)
        self.l1.append(self.s)
    def avg(self,mark):
        self.l1.append(self.s/len(mark))'''

    def display1(self):
        print(self.l)

    '''def display(self):
        for i in self.l:
            if self.Id in self.l:
                self.k.append(i)
        print(self.l)'''
    
ob = mark()
'''
ob.total(1,[80,78,77])
ob.avg([80,78,77])
ob.total(2,[69,70,66])'''
ob.display()
# Out:
# []

# %%
import mysql.connector

class Mydatabase:
    def __init__(self):
        self.mydb = mysql.connector.connect(
                    host = 'localhost',
                    user = 'root',
                    password = 'root@39',
                    database = 'shop_owner'
                )
        self.mycursor = self.mydb.cursor()
    def sum(self,col):
        self.mycursor.execute(f"SELECT SUM({col}) from products")
        self.myresult = self.mycursor.fetchall()
        print(self/re)

    def display(self,tab):
        self.mycursor.execute(f"SELECT * from {tab}")
        self.myresult = self.mycursor.fetchall()
        for i in self.myresult:
            print(i)
obj = Mydatabase()
obj.display('products')
# Out:
# (1, 'Trek 820 - 2016', 2016, Decimal('379.99'))
# (2, 'Ritchey Timberwolf Frameset - 2016', 2016, Decimal('749.99'))
# (3, 'Surly Wednesday Frameset - 2016', 2016, Decimal('999.99'))
# (4, 'Trek Fuel EX 8 29 - 2016', 2016, Decimal('2899.99'))
# (5, 'Heller Shagamaw Frame - 2016', 2016, Decimal('1320.99'))
# (6, 'Surly Ice Cream Truck Frameset - 2016', 2016, Decimal('469.99'))
# (7, 'Trek Slash 8 27.5 - 2016', 2016, Decimal('3999.99'))
# (8, 'Trek Remedy 29 Carbon Frameset - 2016', 2016, Decimal('1799.99'))
# (9, 'Trek Conduit+ - 2016', 2016, Decimal('2999.99'))
# (10, 'Surly Straggler - 2016', 2016, Decimal('1549.00'))
# (11, 'Surly Straggler 650b - 2016', 2016, Decimal('1680.99'))
# (12, 'Electra Townie Original 21D - 2016', 2016, Decimal('549.99'))
# (13, 'Electra Cruiser 1 (24-Inch) - 2016', 2016, Decimal('269.99'))
# (14, "Electra Girl's Hawaii 1 (16-inch) - 2015/2016", 2016, Decimal('269.99'))
# (15, 'Electra Moto 1 - 2016', 2016, Decimal('529.99'))
