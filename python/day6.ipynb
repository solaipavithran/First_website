# %% [markdown]
# ##database connect using python

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.1.0-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Downloading mysql_connector_python-9.1.0-cp312-cp312-win_amd64.whl (16.1 MB)
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.9/16.1 MB 27.7 MB/s eta 0:00:01
#    -------- ------------------------------- 3.2/16.1 MB 41.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.6/16.1 MB 47.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/16.1 MB 50.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.0/16.1 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/16.1 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.1 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.1 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.1 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.1 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 25.2 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'root@39'
)

mycursor = mydb.cursor()

mycursor.execute('CREATE DATABASE shop_owner')

# %%
mycursor.execute('SHOW DATABASES')

# %%
for i in mycursor:
    print(i)
# Out:
# ('assignment1',)
# ('classicmodels',)
# ('information_schema',)
# ('mphasis',)
# ('mysql',)
# ('performance_schema',)
# ('raviram',)
# ('shop',)
# ('shop_owner',)
# ('supermarket',)
# ('sys',)

# %%
mydb = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'root@39',
    database = 'shop_owner'
)

mycursor = mydb.cursor()
mycursor.execute('CREATE TABLE customers (name varchar(225),address varchar(255))')

print('table created')
# Out:
# table created

# %%
mycursor.execute("ALTER TABLE customers ADD COLUMN id  int AUTO_INCREMENT PRIMARY KEY")

# %%
sql = 'INSERT INTO customers(name,address) VALUES (%s,%s)'
val = ('john','highway 21')
mycursor.execute(sql,val)

mydb.commit()
print(mycursor.rowcount,'record inserted')
# Out:
# 1 record inserted

# %%
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = [
    ("peter", "low street 3"),
    ("amy", "high avenue 7"),
    ("john", "oak road 10"),
    ("sarah", "pine street 15"),
    ("michael", "maple lane 22"),
    ("jessica", "elm drive 5"),
    ("david", "cedar court 9"),
    ("emma", "birch boulevard 18"),
    ("daniel", "willow way 13"),
    ("linda", "spruce street 12")
]

mycursor.executemany(sql,val)

mydb.commit()

print(mycursor.rowcount,'inserted')
# Out:
# 10 inserted

# %%
mycursor.execute("SELECT * from customers")
myresult = mycursor.fetchall()
print(myresult)
for i in myresult:
    print(i)
# Out:
# [('john', 'highway 21', 1), ('peter', 'low street 3', 2), ('amy', 'high avenue 7', 3), ('john', 'oak road 10', 4), ('sarah', 'pine street 15', 5), ('michael', 'maple lane 22', 6), ('jessica', 'elm drive 5', 7), ('david', 'cedar court 9', 8), ('emma', 'birch boulevard 18', 9), ('daniel', 'willow way 13', 10), ('linda', 'spruce street 12', 11)]
# ('john', 'highway 21', 1)
# ('peter', 'low street 3', 2)
# ('amy', 'high avenue 7', 3)
# ('john', 'oak road 10', 4)
# ('sarah', 'pine street 15', 5)
# ('michael', 'maple lane 22', 6)
# ('jessica', 'elm drive 5', 7)
# ('david', 'cedar court 9', 8)
# ('emma', 'birch boulevard 18', 9)
# ('daniel', 'willow way 13', 10)
# ('linda', 'spruce street 12', 11)

# %%
mycursor.execute("SELECT * from customers where address = 'highway 21'")
myresult = mycursor.fetchall()

for i in myresult:
    print(i)
# Out:
# ('john', 'highway 21', 1)

# %%
mycursor.execute("DELETE  from customers where address = 'highway 21'")
myresult = mycursor.fetchall()
print(myresult)
# Out:
# []

# %%
mycursor.execute("SELECT * from customers")
myresult = mycursor.fetchall()
for i in myresult:
    print(i)
# Out:
# ('peter', 'low street 3', 2)
# ('amy', 'high avenue 7', 3)
# ('john', 'oak road 10', 4)
# ('sarah', 'pine street 15', 5)
# ('michael', 'maple lane 22', 6)
# ('jessica', 'elm drive 5', 7)
# ('david', 'cedar court 9', 8)
# ('emma', 'birch boulevard 18', 9)
# ('daniel', 'willow way 13', 10)
# ('linda', 'spruce street 12', 11)

# %%
mycursor.execute("UPDATE customers set address = 'highway 21' WHERE address = 'low street 3' ")
myresult = mycursor.fetchall()
print(myresult)
# Out:
# []

# %%
mycursor.execute("SELECT * from customers")
myresult = mycursor.fetchall()
for i in myresult:
    print(i)
# Out:
# ('peter', 'highway 21', 2)
# ('amy', 'high avenue 7', 3)
# ('john', 'oak road 10', 4)
# ('sarah', 'pine street 15', 5)
# ('michael', 'maple lane 22', 6)
# ('jessica', 'elm drive 5', 7)
# ('david', 'cedar court 9', 8)
# ('emma', 'birch boulevard 18', 9)
# ('daniel', 'willow way 13', 10)
# ('linda', 'spruce street 12', 11)

# %%
import mysql.connector

class Mydatabase:
    def __init__(self):
        self.mydb = mysql.connector.connect(
                    host = 'localhost',
                    user = 'root',
                    password = 'root@39',
                    database = 'shop_owner'
                )
        self.mycursor = mydb.cursor()
    def insert(self,val):
        sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
        if len(val) > 1:
            self.mycursor.executemany(sql,val)
        else:
            mycursor.execute(sql,val)
        self.mydb.commit()
        
    def delete(self,add):
        self.mycursor.execute(f"DELETE  from customers where address = '{add}'")
    def update(self,upd):
        self.mycursor.execute(f"UPDATE customers set address = 'highway 21' WHERE address = {upd} ")
        
    def display(self,tab):
        self.mycursor.execute(f"SELECT * from {tab}")
        self.myresult = self.mycursor.fetchall()
        for i in self.myresult:
            print(i)
obj = Mydatabase()
#obj.display('customers')
obj.delete('pine street 15')
#obj.display('customers')
#obj.insert([("peter", "low street 3"),("michael", "maple lane 22")])
obj.display('customers')

#obj.display()
# Out:
# ('jessica', 'elm drive 5', 7)
# ('david', 'cedar court 9', 8)
# ('emma', 'birch boulevard 18', 9)
# ('daniel', 'willow way 13', 10)
# ('linda', 'spruce street 12', 11)
# ('peter', 'low street 3', 12)
# ('michael', 'maple lane 22', 13)

# %%
import mysql.connector

class Mydatabase:
    def __init__(self):
        self.mydb = mysql.connector.connect(
                    host = 'localhost',
                    user = 'root',
                    password = 'root@39',
                    database = 'shop_owner'
                )
        self.mycursor = mydb.cursor()
    def display(self,tab):
        self.mycursor.execute(f"SELECT * from {tab}")
        self.myresult = self.mycursor.fetchall()
        for i in self.myresult:
            print(i)
obj = Mydatabase()
obj.display('products')
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[49], line 18
#      16             print(i)
#      17 obj = Mydatabase()
# ---> 18 obj.display('products')
#
# Cell In[49], line 14, in Mydatabase.display(self, tab)
#      12 def display(self,tab):
#      13     self.mycursor.execute(f"SELECT * from {tab}")
# ---> 14     self.myresult = self.mycursor.fetchall()
#      15     for i in self.myresult:
#      16         print(i)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\cursor.py:923, in MySQLCursor.fetchall(self)
#     920 if not self._have_unread_result():
#     921     return []
# --> 923 (rows, eof) = self._connection.get_rows()
#     924 if self._nextrow[0]:
#     925     rows.insert(0, self._nextrow[0])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:725, in MySQLConnection.get_rows(self, count, binary, columns, raw, prep_stmt)
#     723 except Error as err:
#     724     self.unread_result = False
# --> 725     raise err
#     727 rows, eof_p = rows
#     728 if (
#     729     not (binary or raw)
#     730     and self._columns_desc is not None
#     731     and rows
#     732     and hasattr(self, "converter")
#     733 ):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:720, in MySQLConnection.get_rows(self, count, binary, columns, raw, prep_stmt)
#     716         rows = self._protocol.read_binary_result(
#     717             self._socket, columns, count, charset
#     718         )
#     719     else:
# --> 720         rows = self._protocol.read_text_result(
#     721             self._socket, self._server_version, count=count
#     722         )
#     723 except Error as err:
#     724     self.unread_result = False
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\protocol.py:653, in MySQLProtocol.read_text_result(self, sock, version, count)
#     651         rows.append(rowdata)
#     652     elif eof is None and rowdata is None:
# --> 653         raise get_exception(packet)
#     654     i += 1
#     655 return rows, eof
#
# DatabaseError: 1412 (HY000): Table definition has changed, please retry transaction

# %%
pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp312-cp312-win_amd64.whl (926 kB)
#    ---------------------------------------- 0.0/926.7 kB ? eta -:--:--
#    -------------------------- ------------ 624.6/926.7 kB 19.2 MB/s eta 0:00:01
#    --------------------------------------  921.6/926.7 kB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 926.7/926.7 kB 7.3 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.6 kB ? eta -:--:--
#    --------------------------------------  307.2/313.6 kB 18.6 MB/s eta 0:00:01
#    --------------------------------------  307.2/313.6 kB 18.6 MB/s eta 0:00:01
#    --------------------------------------  307.2/313.6 kB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 313.6/313.6 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
from bson import SON
 
client = MongoClient('localhost', 27017)
 
db = client.newdb
 
people = db.people
 
people.insert_one({'name': 'john','age':20})
people.insert_one({'name': 'lisa','age':21})
people.insert_one({'name': 'mia','age':22})

# %%
listOne = [20, 40, 60, 80]
listTwo = [20, 40, 60, 80,[20, 40, 60, 80]]

print(listOne == listTwo)
print(listOne is listTwo)
# Out:
# False
# False

# %%
sampleList = ["Jon", "Kelly", "Jessa"]
sampleList.append(2, "Scott")
print(sampleList)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 sampleList = ["Jon", "Kelly", "Jessa"]
# ----> 2 sampleList.append(2, "Scott")
#       3 print(sampleList)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
print(type(0xfffff))
# Out:
# <class 'int'>

# %%
x = 100
y = 50
print(x or y)
# Out:
# 100

# %%
print('%d %d %.2f' % (11, '22', 11.22))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 print('%d %d %.2f' % (11, '22', 11.22))
#
# TypeError: %d format: a real number is required, not str

# %%
dic = {1:4,2:6}
for i in dic:
    print(i)
# Out:
# 1
# 2

# %%
for num in range(10, 14):
   for i in range(2, num):
       if num%i == 1:
          print(num)
          break
# Out:
# 10
# 11
# 12
# 13
