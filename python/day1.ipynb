# %%
print("hello")
# Out:
# hello

# %%
a=4.4
b='s'
print(type(b))
print(type(a))
# Out:
# <class 'str'>
# <class 'float'>

# %%
a = int(input("enter a number :"))
print(a)
# Out:
# 67

# %%
#a = input()
num = int(input("enter number to check -ve or +ve"))
if num>0:
    print("the number is +ve")
elif num ==0:
    print("the number is 0")
elif num<0:
    print("the number is -ve")
# Out:
# the number is -ve

# %%
for i in range(5,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range(1,3):
    print(i)
    break
else:
    print("hello")
# Out:
# 1

# %%
S = input()
a = ['a','e','i','o','u']
countV = 0
countC = 0
for i in S:
    if i in a:
        countV +=1
    else:
        countC +=1 
print(f'count Vowles = {countV} \ncount consonts = {countC}')
# Out:
# count Vowles = 3
# count consonts = 2

# %%
#list com

x1 = [1,2,3,4,5,5,2,3,3,2]
x2 = [i for i in x1 if i == 2]
print(x2)
# Out:
# [2, 2, 2]

# %%
a = 0
b= 1
l = [0,1]
n=5
if n>2:
    for i in range(n):
        c = a+b
        l.append(c)
        a = b
        b = c
    print(l)
else:
    print(l)
# Out:
# [0, 1, 1, 2, 3, 5, 8]

# %%
l = list(map(int,input().split()))
print(l)
# Out:
# [1, 2, 4, 5]

# %%
a  = set()
a = {1,3,2,4}
b = set ()
b = {2,1,6,1}
print(a^b)
# Out:
# {3, 4, 6}

# %%
l = [1000,2000,5000,4000,7000]
r  = [10,12,14,8,9]
y = [1,2,3,4,5]
k = []
for i in range(len(l)):
    a  = l[i]+(l[i]*y[i]*r[i])/100
    k.append(a)
print(k)
# Out:
# [1100.0, 2480.0, 7100.0, 5280.0, 10150.0]

# %%
dic = {}

for i in range(2):
    a = input()
    b = input()
    dic[a] = b
print(dic)
dic.update({"hi":4})
print(dic)
# Out:
# {'so': '2', 'av': '4'}
# {'so': '2', 'av': '4', 'hi': 4}

# %%
dic = {"solai":3,"hi":5,"world":4}
l1 =[]
l2 = []
for i in dic.values():
    l1.append(i)
for j in dic.keys():
    l2.append(j)
print(l1,l2)
dic = {}
for i in range(len(l1)):
    dic[l1[i]] = l2[i]
print(dic.values())
# Out:
# [3, 5, 4] ['solai', 'hi', 'world']
# dict_values(['solai', 'hi', 'world'])

# %%
l = ['rui','kandera','hello','sun','world']
dic = {}
for i in l:
    dic[i] = len(i)
print(dic)
# dic comprehenshion
d = {x:len(x) for x in l}
print(d)
# Out:
# {'rui': 3, 'kandera': 7, 'hello': 5, 'sun': 3, 'world': 5}
# {'rui': 3, 'kandera': 7, 'hello': 5, 'sun': 3, 'world': 5}

# %%
print(l)
l.append(0)
print(any(l))
# Out:
# ['rui', 'kandera', 'hello', 'sun', 'world', 'hi', 'hi', 0]
# True

# %%
print(all(l))
# Out:
# False

# %%
k = 1
n=3
l = n*11
for i in range(n,l,n):
    print(f'10 x {k} = {i}')
    k +=1
# Out:
# 10 x 1 = 3
# 10 x 2 = 6
# 10 x 3 = 9
# 10 x 4 = 12
# 10 x 5 = 15
# 10 x 6 = 18
# 10 x 7 = 21
# 10 x 8 = 24
# 10 x 9 = 27
# 10 x 10 = 30

# %%
s  = "HwoWesD"
l = [3,3,4]
Ucount = 0
Lcount = 0
Ncount = 0
for i in s:
    if i.isupper():
        Ucount +=1
    else:
        Lcount +=1
print(Ucount,Lcount)
# Out:
# 3 4

# %%
Ncount = 0
l = [3,3,4]
for i in l:
        if type(i) == int:
                Ncount += 1 

print(Ncount)
# Out:
# 3

# %%
l = ['rui','kandera','hello','sun','world']
dic = {}
for i in l:
    dic[i] = len(i)
print(dic)
# Out:
# {'rui': 3, 'kandera': 7, 'hello': 5, 'sun': 3, 'world': 5}

# %%
dic = {}
for i in range(97,119):
    dic[chr(i)] = i
print(dic)
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108, 'm': 109, 'n': 110, 'o': 111, 'p': 112, 'q': 113, 'r': 114, 's': 115, 't': 116, 'u': 117, 'v': 118}

# %%
import string
dic = {}
r=string.ascii_lowercase
for i in r:
    dic[i] = ord(i)
print(dic)
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108, 'm': 109, 'n': 110, 'o': 111, 'p': 112, 'q': 113, 'r': 114, 's': 115, 't': 116, 'u': 117, 'v': 118, 'w': 119, 'x': 120, 'y': 121, 'z': 122}

# %%
text = "the quick brown fox jumps over the lazy dog"
dic = {}
for i in text.split(" "):
    if i not in dic:
        dic[i] = 1
    else:
        dic[i] +=1
print(dic)
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1}

# %%
n = ['nikhil','anand','shiva','maga','ram']
l = [1000,2000,6000,10000,2500]
r  = [8,7,7.5,9,6]
y = [1,2,3,4,5]
#k = []
for i in range(len(l)):
    a  = l[i]+(l[i]*y[i]*r[i])/100
    print(f'name {n[i]} invested {l[i]} got a return of principal interest {a}')
print()
for i in range(len(l)):
    c = l[i]*(1 +(r[i]/100))**y[i]
    print(f'name {n[i]} invested {l[i]} got a return of compound interest {round(c,2)}')
# Out:
# name nikhil invested 1000 got a return of principal interest 1080.0
# name anand invested 2000 got a return of principal interest 2280.0
# name shiva invested 6000 got a return of principal interest 7350.0
# name maga invested 10000 got a return of principal interest 13600.0
# name ram invested 2500 got a return of principal interest 3250.0
#
# name nikhil invested 1000 got a return of compound interest 1080.0
# name anand invested 2000 got a return of compound interest 2289.8
# name shiva invested 6000 got a return of compound interest 7453.78
# name maga invested 10000 got a return of compound interest 14115.82
# name ram invested 2500 got a return of compound interest 3345.56

# %%
s = 'my name is alex'
k = ""
n  = s.split()
for i in range(len(n)-1,-1,-1):
    k += n[i] + " "
print(k)
print(n[::-1])
r=" ".join(n[::-1])
r
# Out:
# ['alex', 'is', 'name', 'my']
# 'alex is name my'

# %%
dic = {'abd':42,'solai':20,'pavithran':43}
k = {}
#for i in dic.items():
for i in sorted(dic.items()):
    k[i[0]] = i[1]
print(k)
# Out:
# {'abd': 42, 'pavithran': 43, 'solai': 20}

# %%
sample_dict = {'apple': 5, 'banana': 2, 'orange': 8, 'grape': 1}

# Sorting using a for loop
sorted_dict = {}
for x in sorted(sample_dict, key=sample_dict.get):
    sorted_dict[x] = sample_dict[x]

print(sorted_dict)
# Out:
# {'grape': 1, 'banana': 2, 'apple': 5, 'orange': 8}

# %%
print(sample_dict.get("apple"))
# Out:
# 5

# %%
s = "abcd"
k = ""
for i in s:
    k+=i
    print(k)
# Out:
# a
# ab
# abc
# abcd

# %%
s = 'abcd'
for i in range(len(s)):
    for j in range(i,len(s)):
        print(s[i:j+1], end = " ")
    print()
# Out:
# a ab abc abcd
# b bc bcd
# c cd
# d

# %%
l = [1,4,5,6,7,8] 
n = 10

for i in range(len(l)):
    for j in range(i,len(l)):
        if n == l[i]+l[j]:
            print(i,j)
# Out:
# 1 3
# 2 2
